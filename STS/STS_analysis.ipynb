# %%
push!(LOAD_PATH, pwd())
using AutoSTS
# Out:
# ┌ Info: Precompiling AutoSTS [top-level]
# └ @ Base loading.jl:1260

# %%
using DelimitedFiles
using Plots, LaTeXStrings

# %%
data_path_1 = "data/AB60_Transmon_cav1_S21vsFvsV_fr5.965_5.972_Pr-40_V-0.3_0.3_0.01_T0_40dBHatt_181042_mag.dat";

# %%
data_path_2 = "data/AB60_Transmon_S21vsFvsV_fr6.06_6.07_Pr-37_V-0.3_0.3_0.01_T0_50dBHatt_152511_mag.dat";

# %%
sts1 = STS(data_path_1)
sts2 = STS(data_path_2);

# %%
heatmap(sts1)

# %%
f_r = extract_resonance_freqs(sts1)
plot(sts1.V_range, f_r, ylims=sts1.freq_lims, seriestype=:scatter)

# %%
plot_slice(sts1, -0.2)
